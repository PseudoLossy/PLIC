# %%
import os
from PIL import Image

def convert_images_to_jpg(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through all files in the input folder
    for filename in os.listdir(input_folder):
        if True:
            # Open the image
            img_path = os.path.join(input_folder, filename)
            img = Image.open(img_path)

            # Convert image to RGB (this removes the alpha channel if it exists)
            img_rgb = img.convert('RGB')

            # Create a new filename with .jpg extension
            new_filename = os.path.splitext(filename)[0] + '.jpg'

            # Save the image as a JPEG in the output folder
            img_rgb.save(os.path.join(output_folder, new_filename), format='JPEG')

            print(f'Converted and saved {filename} as {new_filename}')

# Example usage
input_folder = './images_dataset'
output_folder = './hific_images_dataset'

convert_images_to_jpg(input_folder, output_folder)
# Out:
# Converted and saved 001.webp as 001.jpg
# Converted and saved 002.webp as 002.jpg
# Converted and saved 003.webp as 003.jpg
# Converted and saved 004.webp as 004.jpg
# Converted and saved 005.webp as 005.jpg
# Converted and saved 006.jpg as 006.jpg
# Converted and saved 007.webp as 007.jpg
# Converted and saved 008.webp as 008.jpg
# Converted and saved 009.webp as 009.jpg
# Converted and saved 010.webp as 010.jpg
# Converted and saved 011.webp as 011.jpg
# Converted and saved 012.webp as 012.jpg
# Converted and saved 013.webp as 013.jpg
# Converted and saved 015.webp as 015.jpg
# Converted and saved 016.jpg as 016.jpg
# Converted and saved 017.webp as 017.jpg
# Converted and saved 018.webp as 018.jpg
# Converted and saved 019.webp as 019.jpg
# Converted and saved 020.webp as 020.jpg
# Converted and saved 021.webp as 021.jpg
# Converted and saved 022.jpg as 022.jpg
# Converted and saved 023.webp as 023.jpg
# Converted and saved 024.jpg as 024.jpg
# Converted and saved 025.webp as 025.jpg
# Converted and saved 026.webp as 026.jpg
# Converted and saved 027.webp as 027.jpg
# Converted and saved 028.webp as 028.jpg
# Converted and saved 029.webp as 029.jpg
# Converted and saved 030.webp as 030.jpg
# Converted and saved 031.webp as 031.jpg
# Converted and saved 032.webp as 032.jpg
# Converted and saved 033.webp as 033.jpg
# Converted and saved 034.webp as 034.jpg
# Converted and saved 035.webp as 035.jpg
# Converted and saved 036.webp as 036.jpg
# Converted and saved 037.webp as 037.jpg
# Converted and saved 038.webp as 038.jpg
# Converted and saved 039.webp as 039.jpg
# Converted and saved 040.webp as 040.jpg
# Converted and saved 041.webp as 041.jpg
# Converted and saved 042.webp as 042.jpg
# Converted and saved 043.jpg as 043.jpg
# Converted and saved 044.webp as 044.jpg
# Converted and saved 045.webp as 045.jpg
# Converted and saved 046.webp as 046.jpg
# Converted and saved 047.webp as 047.jpg
# Converted and saved 048.webp as 048.jpg
# Converted and saved 049.webp as 049.jpg
# Converted and saved 050.webp as 050.jpg
# Converted and saved 051.JPG as 051.jpg
# Converted and saved 052.jpg as 052.jpg
# Converted and saved 053.JPG as 053.jpg
# Converted and saved 054.jpg as 054.jpg
# Converted and saved 055.jpg as 055.jpg
# Converted and saved 056.webp as 056.jpg
# Converted and saved 057.jpg as 057.jpg
# Converted and saved 058.jpg as 058.jpg
# Converted and saved 059.jpg as 059.jpg
# Converted and saved 060.jpg as 060.jpg
# Converted and saved 061.jpg as 061.jpg
# Converted and saved 062.jpg as 062.jpg
# Converted and saved 063.jpg as 063.jpg
# Converted and saved 064.jpg as 064.jpg
# Converted and saved 065.jpg as 065.jpg
# Converted and saved 066.jpg as 066.jpg
# Converted and saved 067.jpg as 067.jpg
# Converted and saved 068.jpg as 068.jpg
# Converted and saved 069.jpg as 069.jpg
# Converted and saved 070.jpg as 070.jpg
# Converted and saved 071.jpg as 071.jpg
# Converted and saved 072.jpg as 072.jpg
# Converted and saved 073.jpg as 073.jpg
# Converted and saved 074.jpg as 074.jpg
# Converted and saved 075.jpg as 075.jpg
# Converted and saved 076.jpg as 076.jpg
# Converted and saved 077.webp as 077.jpg
# Converted and saved 078.jpg as 078.jpg
# Converted and saved 079.jpg as 079.jpg
# Converted and saved 080.jpg as 080.jpg
# Converted and saved 081.jpg as 081.jpg
# Converted and saved 082.jpg as 082.jpg
# Converted and saved 083.jpg as 083.jpg
# Converted and saved 084.jpg as 084.jpg
# Converted and saved 085.jpg as 085.jpg
# Converted and saved 086.jpg as 086.jpg
# Converted and saved 087.jpg as 087.jpg
# Converted and saved 088.jpg as 088.jpg
# Converted and saved 089.jpg as 089.jpg
# Converted and saved 090.jpg as 090.jpg
# Converted and saved 091.jpg as 091.jpg
# Converted and saved 092.jpg as 092.jpg
# Converted and saved 093.jpg as 093.jpg
# Converted and saved 094.jpg as 094.jpg
# Converted and saved 095.jpg as 095.jpg
# Converted and saved 096.jpg as 096.jpg
# Converted and saved 097.jpg as 097.jpg
# Converted and saved 098.jpg as 098.jpg
# Converted and saved 099.jpg as 099.jpg
# Converted and saved 100.jpg as 100.jpg
# Converted and saved 101.webp as 101.jpg
# Converted and saved 102.webp as 102.jpg
# Converted and saved 103.JPG as 103.jpg
# Converted and saved 104.webp as 104.jpg
# Converted and saved 105.jpg as 105.jpg
# Converted and saved 106.webp as 106.jpg
# Converted and saved 108.jpeg as 108.jpg
# Converted and saved 109.jpg as 109.jpg
# Converted and saved 110.jpg as 110.jpg
# Converted and saved 111.jpg as 111.jpg
# Converted and saved 112.jpg as 112.jpg
# Converted and saved 113.jpg as 113.jpg
# Converted and saved 114.jpeg as 114.jpg
# Converted and saved 115.jpg as 115.jpg
# Converted and saved 116.jpg as 116.jpg
# Converted and saved 117.jpg as 117.jpg
# Converted and saved 118.jpg as 118.jpg
# Converted and saved 119.jpg as 119.jpg
# Converted and saved 120.jpeg as 120.jpg
# Converted and saved 121.jpg as 121.jpg
# Converted and saved 122.jpg as 122.jpg
# Converted and saved 123.jpg as 123.jpg
# Converted and saved 124.jpeg as 124.jpg
# Converted and saved 125.jpg as 125.jpg
# Converted and saved 126.jpg as 126.jpg
# Converted and saved 127.jpeg as 127.jpg
# Converted and saved 128.jpg as 128.jpg
# Converted and saved 129.jpg as 129.jpg
# Converted and saved 130.jpg as 130.jpg
# Converted and saved 131.jpg as 131.jpg
# Converted and saved 132.jpeg as 132.jpg
# Converted and saved 133.jpg as 133.jpg
# Converted and saved 134.jpg as 134.jpg
# Converted and saved 135.jpg as 135.jpg
# Converted and saved 136.jpg as 136.jpg
# Converted and saved 137.jpg as 137.jpg
# Converted and saved 138.jpg as 138.jpg
# Converted and saved 139.jpeg as 139.jpg
# Converted and saved 140.jpeg as 140.jpg
# Converted and saved 141.jpg as 141.jpg
# Converted and saved 142.jpg as 142.jpg
# Converted and saved 143.jpg as 143.jpg
# Converted and saved 144.jpg as 144.jpg
# Converted and saved 145.jpg as 145.jpg
# Converted and saved 146.jpg as 146.jpg
# Converted and saved 147.jpg as 147.jpg
# Converted and saved 148.jpg as 148.jpg
# Converted and saved 149.jpg as 149.jpg
# Converted and saved 150.jpg as 150.jpg

# %%
import os
from PIL import Image

def nearest_multiple_of_8(value):
    return round(value / 8) * 8  # Rounds to the nearest multiple of 8

def resize_images(input_folder, output_folder, scale_factor=0.6):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through all jpg files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.jpg'):
            img_path = os.path.join(input_folder, filename)
            img = Image.open(img_path)

            # Get original dimensions
            original_width, original_height = img.size

            # Calculate new dimensions (60% of original size)
            new_width = int(original_width * scale_factor)
            new_height = int(original_height * scale_factor)

            # Adjust dimensions to the nearest multiple of 8
            new_width = nearest_multiple_of_8(new_width)
            new_height = nearest_multiple_of_8(new_height)

            # Resize the image
            resized_img = img.resize((new_width, new_height), Image.BICUBIC)

            # Save the resized image in the output folder
            resized_img.save(os.path.join(output_folder, filename))

            print(f'Resized and saved {filename} to {new_width}x{new_height}')

# Example usage
input_folder = './hific_images_dataset'
output_folder = './reduced_images_dataset'

resize_images(input_folder, output_folder)
# Out:
# Resized and saved 001.jpg to 616x408
# Resized and saved 002.jpg to 616x408
# Resized and saved 003.jpg to 496x616
# Resized and saved 004.jpg to 408x616
# Resized and saved 005.jpg to 616x408
# Resized and saved 006.jpg to 616x408
# Resized and saved 007.jpg to 616x608
# Resized and saved 008.jpg to 616x544
# Resized and saved 009.jpg to 616x408
# Resized and saved 010.jpg to 616x408
# Resized and saved 011.jpg to 616x408
# Resized and saved 012.jpg to 616x408
# Resized and saved 013.jpg to 616x408
# Resized and saved 015.jpg to 616x408
# Resized and saved 016.jpg to 480x288
# Resized and saved 017.jpg to 616x408
# Resized and saved 018.jpg to 616x408
# Resized and saved 019.jpg to 616x408
# Resized and saved 020.jpg to 616x408
# Resized and saved 021.jpg to 616x408
# Resized and saved 022.jpg to 488x616
# Resized and saved 023.jpg to 616x408
# Resized and saved 024.jpg to 616x408
# Resized and saved 025.jpg to 616x408
# Resized and saved 026.jpg to 616x408
# Resized and saved 027.jpg to 616x408
# Resized and saved 028.jpg to 616x408
# Resized and saved 029.jpg to 464x616
# Resized and saved 030.jpg to 616x336
# Resized and saved 031.jpg to 616x344
# Resized and saved 032.jpg to 616x344
# Resized and saved 033.jpg to 616x408
# Resized and saved 034.jpg to 616x408
# Resized and saved 035.jpg to 616x408
# Resized and saved 036.jpg to 616x344
# Resized and saved 037.jpg to 616x408
# Resized and saved 038.jpg to 616x408
# Resized and saved 039.jpg to 616x416
# Resized and saved 040.jpg to 616x344
# Resized and saved 041.jpg to 616x336
# Resized and saved 042.jpg to 616x344
# Resized and saved 043.jpg to 464x368
# Resized and saved 044.jpg to 616x344
# Resized and saved 045.jpg to 616x344
# Resized and saved 046.jpg to 616x344
# Resized and saved 047.jpg to 616x344
# Resized and saved 048.jpg to 616x344
# Resized and saved 049.jpg to 616x344
# Resized and saved 050.jpg to 616x456
# Resized and saved 051.jpg to 616x464
# Resized and saved 052.jpg to 616x408
# Resized and saved 053.jpg to 616x320
# Resized and saved 054.jpg to 480x600
# Resized and saved 055.jpg to 432x616
# Resized and saved 056.jpg to 616x408
# Resized and saved 057.jpg to 616x344
# Resized and saved 058.jpg to 608x528
# Resized and saved 059.jpg to 480x600
# Resized and saved 060.jpg to 616x408
# Resized and saved 061.jpg to 616x616
# Resized and saved 062.jpg to 272x472
# Resized and saved 063.jpg to 616x448
# Resized and saved 064.jpg to 616x464
# Resized and saved 065.jpg to 616x344
# Resized and saved 066.jpg to 616x408
# Resized and saved 067.jpg to 616x392
# Resized and saved 068.jpg to 616x408
# Resized and saved 069.jpg to 616x472
# Resized and saved 070.jpg to 616x304
# Resized and saved 071.jpg to 408x616
# Resized and saved 072.jpg to 616x408
# Resized and saved 073.jpg to 616x464
# Resized and saved 074.jpg to 616x472
# Resized and saved 075.jpg to 616x408
# Resized and saved 076.jpg to 616x408
# Resized and saved 077.jpg to 616x408
# Resized and saved 078.jpg to 376x616
# Resized and saved 079.jpg to 616x520
# Resized and saved 080.jpg to 616x400
# Resized and saved 081.jpg to 616x488
# Resized and saved 082.jpg to 616x408
# Resized and saved 083.jpg to 616x296
# Resized and saved 084.jpg to 616x408
# Resized and saved 085.jpg to 616x616
# Resized and saved 086.jpg to 616x304
# Resized and saved 087.jpg to 616x408
# Resized and saved 088.jpg to 616x408
# Resized and saved 089.jpg to 616x400
# Resized and saved 090.jpg to 616x280
# Resized and saved 091.jpg to 272x496
# Resized and saved 092.jpg to 616x616
# Resized and saved 093.jpg to 616x408
# Resized and saved 094.jpg to 616x344
# Resized and saved 095.jpg to 616x408
# Resized and saved 096.jpg to 616x408
# Resized and saved 097.jpg to 616x304
# Resized and saved 098.jpg to 480x600
# Resized and saved 099.jpg to 616x408
# Resized and saved 100.jpg to 408x616
# Resized and saved 101.jpg to 408x616
# Resized and saved 102.jpg to 616x408
# Resized and saved 103.jpg to 616x440
# Resized and saved 104.jpg to 488x616
# Resized and saved 105.jpg to 488x616
# Resized and saved 106.jpg to 488x616
# Resized and saved 108.jpg to 616x344
# Resized and saved 109.jpg to 488x616
# Resized and saved 110.jpg to 344x608
# Resized and saved 111.jpg to 320x480
# Resized and saved 112.jpg to 616x408
# Resized and saved 113.jpg to 464x616
# Resized and saved 114.jpg to 416x616
# Resized and saved 115.jpg to 408x616
# Resized and saved 116.jpg to 376x616
# Resized and saved 117.jpg to 408x616
# Resized and saved 118.jpg to 616x344
# Resized and saved 119.jpg to 616x408
# Resized and saved 120.jpg to 616x480
# Resized and saved 121.jpg to 488x616
# Resized and saved 122.jpg to 616x400
# Resized and saved 123.jpg to 616x616
# Resized and saved 124.jpg to 416x616
# Resized and saved 125.jpg to 616x376
# Resized and saved 126.jpg to 608x408
# Resized and saved 127.jpg to 400x616
# Resized and saved 128.jpg to 616x464
# Resized and saved 129.jpg to 616x488
# Resized and saved 130.jpg to 616x408
# Resized and saved 131.jpg to 616x408
# Resized and saved 132.jpg to 408x616
# Resized and saved 133.jpg to 488x616
# Resized and saved 134.jpg to 616x408
# Resized and saved 135.jpg to 488x616
# Resized and saved 136.jpg to 616x408
# Resized and saved 137.jpg to 616x408
# Resized and saved 138.jpg to 616x440
# Resized and saved 139.jpg to 616x408
# Resized and saved 140.jpg to 488x616
# Resized and saved 141.jpg to 464x616
# Resized and saved 142.jpg to 488x608
# Resized and saved 143.jpg to 408x616
# Resized and saved 144.jpg to 408x616
# Resized and saved 145.jpg to 408x616
# Resized and saved 146.jpg to 616x408
# Resized and saved 147.jpg to 616x528
# Resized and saved 148.jpg to 616x488
# Resized and saved 149.jpg to 616x344
# Resized and saved 150.jpg to 616x408
